# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DATASET_PATH = "dataset"

# %%
sets = pd.read_csv(DATASET_PATH + "/sets.csv")

themes = pd.read_csv(DATASET_PATH + "/themes.csv")
themes.rename(columns = {'id':'theme_id'}, inplace = True)

sets = sets.merge(themes, on='theme_id', how='left')
sets.rename(columns = {'name_x':'set_name','name_y':'theme_name'}, inplace = True)

sets.set_num.nunique()
# Out:
# 11673

# %%
inv = pd.read_csv(DATASET_PATH + "/inventories.csv")
inv.set_num.nunique()
# Out:
# 11670

# %%
inv = inv.merge(sets, on='set_num', how='left')
inv.set_num.nunique()
# Out:
# 11670

# %%
inv_part = pd.read_csv(DATASET_PATH + "/inventory_parts.csv")

colors = pd.read_csv(DATASET_PATH + "/colors.csv")
colors.rename(columns = {'id':'color_id'}, inplace = True)

inv_part = inv_part.merge(colors, on='color_id', how='left')
inv_part.rename(columns = {'inventory_id':'id'}, inplace = True)
inv_part.shape
# Out:
# (580251, 8)

# %%
df = inv_part.merge(inv, on='id', how='left')
print('Cantidad de tamaticas: ',df.theme_name.nunique())
df.head()
# Out:
# Cantidad de tamaticas:  379
#    id     part_num  color_id  quantity is_spare              name     rgb  \
# 0   1     48379c01        72         1        f  Dark Bluish Gray  6C6E68
# 1   1        48395         7         1        f        Light Gray  9BA19D
# 2   1     mcsport6        25         1        f            Orange  FE8A18
# 3   1       paddle         0         1        f             Black  05131D
# 4   3  11816pr0005        78         1        f       Light Flesh  F6D7B3
#
#   is_trans  version set_num  \
# 0        f        1  7922-1
# 1        f        1  7922-1
# 2        f        1  7922-1
# 3        f        1  7922-1
# 4        f        1  3931-1
#
#                                             set_name  year  theme_id  \
# 0  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 1  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 2  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 3  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 4                                 Emma's Splash Pool  2012       494
#
#    num_parts     theme_name  parent_id
# 0          4  Gravity Games      458.0
# 1          4  Gravity Games      458.0
# 2          4  Gravity Games      458.0
# 3          4  Gravity Games      458.0
# 4         43        Friends        NaN

# %%
# Limpio algunas columnas
df = df.drop(['parent_id', 'theme_id', 'year', 'set_name', 'version', 'is_trans', 'name', 'is_spare',  'quantity',
              'color_id', 'part_num',  'id'], axis = 'columns')
df
# Out:
#            rgb  set_num  num_parts        theme_name
# 0       6C6E68   7922-1          4     Gravity Games
# 1       9BA19D   7922-1          4     Gravity Games
# 2       FE8A18   7922-1          4     Gravity Games
# 3       05131D   7922-1          4     Gravity Games
# 4       F6D7B3   3931-1         43           Friends
# ...        ...      ...        ...               ...
# 580246  05131D  75090-2        253  Star Wars Rebels
# 580247  A0A5A9  75090-2        253  Star Wars Rebels
# 580248  FFFFFF  75090-2        253  Star Wars Rebels
# 580249  05131D  75090-2        253  Star Wars Rebels
# 580250  6C6E68  75090-2        253  Star Wars Rebels
#
# [580251 rows x 4 columns]

# %%
print('Cantidad de sets: {}'.format(df.set_num.nunique()))

#df_g=df.groupby('set_num',as_index=False)['rgb'].nunique()


#df_g=df.groupby('theme_name',as_index=False)['rgb'].nunique()

#df_g=df_g.sort_values(by=['rgb'])



#df_g.plot.bar(x = 'set_num', y = 'rgb')
#df_g.plot.bar(x = 'theme_name', y = 'rgb', figsize = (30,5))
# Out:
# Cantidad de sets: 10713

# %%
#df_d = df.drop_duplicates(ignore_index = True)
#df_d = df_d.drop(['name', 'set_name','num_parts', 'theme_name'], axis = 'columns')
#print (df_d.shape)
#df_d.head()

#df_d.pivot(index= 'set_num', columns = 'color_id', values='rgb')
#df_d.T

# %%
# Frecuency encoder RGB
rgb_frecuency = df.rgb.value_counts(normalize = True).rename_axis('rgb').reset_index(name='rgb_frec')

# Frecuency encoder temáticas
theme_frecuency = df.theme_name.value_counts(normalize = True).rename_axis('theme_name').reset_index(name='theme_frec')

#theme_frecuency.theme_frec.unique().shape
#rgb_frecuency

# %%
# Se agregan n columnas para caracterizar cada theme por sus n colores mas relevantes
n = 10

for i in range(n):
    df['rgb{}'.format(i+1)]=0

# %%
df = df.merge(rgb_frecuency, on='rgb', how='left')
df = df.merge(theme_frecuency, on='theme_name', how='left')
print(df.shape)
df.head()
# Out:
# (580251, 16)
#       rgb set_num  num_parts     theme_name  rgb1  rgb2  rgb3  rgb4  rgb5  \
# 0  6C6E68  7922-1          4  Gravity Games     0     0     0     0     0
# 1  9BA19D  7922-1          4  Gravity Games     0     0     0     0     0
# 2  FE8A18  7922-1          4  Gravity Games     0     0     0     0     0
# 3  05131D  7922-1          4  Gravity Games     0     0     0     0     0
# 4  F6D7B3  3931-1         43        Friends     0     0     0     0     0
#
#    rgb6  rgb7  rgb8  rgb9  rgb10  rgb_frec  theme_frec
# 0     0     0     0     0      0  0.075679    0.000570
# 1     0     0     0     0      0  0.043669    0.000570
# 2     0     0     0     0      0  0.010564    0.000570
# 3     0     0     0     0      0  0.202362    0.000570
# 4     0     0     0     0      0  0.003140    0.028613

# %%
for tematica in df.theme_name.unique():
    df_rgb = df.loc[df.theme_name == tematica].rgb.value_counts()[0:n].rename_axis('rgb').reset_index(name='sum')
    df_rgb = df_rgb.merge(rgb_frecuency, on='rgb', how='left')
    if (n > df_rgb.shape[0]):
        for i in range(df_rgb.shape[0]):
            df.loc[df.theme_name == tematica, 'rgb{}'.format(i+1)] = df_rgb.iat[i,2]
    else:
        for i in range(n):
            df.loc[df.theme_name == tematica, 'rgb{}'.format(i+1)] = df_rgb.iat[i,2]

# %%
df
# Out:
#            rgb  set_num  num_parts        theme_name      rgb1      rgb2  \
# 0       6C6E68   7922-1          4     Gravity Games  0.114923  0.043669
# 1       9BA19D   7922-1          4     Gravity Games  0.114923  0.043669
# 2       FE8A18   7922-1          4     Gravity Games  0.114923  0.043669
# 3       05131D   7922-1          4     Gravity Games  0.114923  0.043669
# 4       F6D7B3   3931-1         43           Friends  0.114923  0.095333
# ...        ...      ...        ...               ...       ...       ...
# 580246  05131D  75090-2        253  Star Wars Rebels  0.095333  0.075679
# 580247  A0A5A9  75090-2        253  Star Wars Rebels  0.095333  0.075679
# 580248  FFFFFF  75090-2        253  Star Wars Rebels  0.095333  0.075679
# 580249  05131D  75090-2        253  Star Wars Rebels  0.095333  0.075679
# 580250  6C6E68  75090-2        253  Star Wars Rebels  0.095333  0.075679
#
#             rgb3      rgb4     rgb5      rgb6      rgb7      rgb8      rgb9  \
# 0       0.202362  0.051455  0.09642  0.066931  0.013117  0.020410  0.023578
# 1       0.202362  0.051455  0.09642  0.066931  0.013117  0.020410  0.023578
# 2       0.202362  0.051455  0.09642  0.066931  0.013117  0.020410  0.023578
# 3       0.202362  0.051455  0.09642  0.066931  0.013117  0.020410  0.023578
# 4       0.202362  0.023578  0.09642  0.002723  0.024417  0.002628  0.001968
# ...          ...       ...      ...       ...       ...       ...       ...
# 580246  0.202362  0.114923  0.09642  0.023578  0.066931  0.006159  0.024417
# 580247  0.202362  0.114923  0.09642  0.023578  0.066931  0.006159  0.024417
# 580248  0.202362  0.114923  0.09642  0.023578  0.066931  0.006159  0.024417
# 580249  0.202362  0.114923  0.09642  0.023578  0.066931  0.006159  0.024417
# 580250  0.202362  0.114923  0.09642  0.023578  0.066931  0.006159  0.024417
#
#            rgb10  rgb_frec  theme_frec
# 0       0.003457  0.075679    0.000570
# 1       0.003457  0.043669    0.000570
# 2       0.003457  0.010564    0.000570
# 3       0.003457  0.202362    0.000570
# 4       0.066931  0.003140    0.028613
# ...          ...       ...         ...
# 580246  0.051455  0.202362    0.005156
# 580247  0.051455  0.095333    0.005156
# 580248  0.051455  0.114923    0.005156
# 580249  0.051455  0.202362    0.005156
# 580250  0.051455  0.075679    0.005156
#
# [580251 rows x 16 columns]

# %%
#for tematica in df.theme_name.unique():
#    df_rgb=pd.DataFrame(df.loc[df.theme_name == tematica].rgb.value_counts()[0:n])
#    if (n > df_rgb.shape[0]):
#        for i in range(df_rgb.shape[0]):
#            df.loc[df.theme_name == tematica, 'rgb{}'.format(i+1)] = df_rgb.index[i]
#    else:
#        for i in range(n):
#            df.loc[df.theme_name == tematica, 'rgb{}'.format(i+1)] = df_rgb.index[i]

# %%
df_d = df.drop(['rgb', 'set_num', 'rgb_frec'], axis = 'columns')
df_d = df_d.drop_duplicates(ignore_index = True)
df_d
# Out:
#       num_parts               theme_name      rgb1      rgb2      rgb3  \
# 0             4            Gravity Games  0.114923  0.043669  0.202362
# 1            43                  Friends  0.114923  0.095333  0.202362
# 2            20               Insectoids  0.202362  0.051455  0.013117
# 3             2                     Town  0.114923  0.202362  0.096420
# 4            10             Supplemental  0.114923  0.096420  0.202362
# ...         ...                      ...       ...       ...       ...
# 6981        447  Star Wars Episode 4/5/6  0.095333  0.202362  0.075679
# 6982        423                   Jungle  0.202362  0.096420  0.043669
# 6983         10    Series 17 Minifigures  0.202362  0.066931  0.114923
# 6984        378                   Jungle  0.202362  0.096420  0.043669
# 6985        253         Star Wars Rebels  0.095333  0.075679  0.202362
#
#           rgb4      rgb5      rgb6      rgb7      rgb8      rgb9     rgb10  \
# 0     0.051455  0.096420  0.066931  0.013117  0.020410  0.023578  0.003457
# 1     0.023578  0.096420  0.002723  0.024417  0.002628  0.001968  0.066931
# 2     0.003657  0.004452  0.003399  0.013170  0.043669  0.096420  0.003395
# 3     0.066931  0.095333  0.051455  0.075679  0.020410  0.043669  0.024417
# 4     0.051455  0.066931  0.043669  0.020410  0.095333  0.013170  0.013117
# ...        ...       ...       ...       ...       ...       ...       ...
# 6981  0.114923  0.043669  0.023578  0.013117  0.024417  0.096420  0.051455
# 6982  0.066931  0.051455  0.013117  0.020410  0.114923  0.005968  0.075679
# 6983  0.095333  0.023578  0.096420  0.002116  0.002040  0.000562  0.007571
# 6984  0.066931  0.051455  0.013117  0.020410  0.114923  0.005968  0.075679
# 6985  0.114923  0.096420  0.023578  0.066931  0.006159  0.024417  0.051455
#
#       theme_frec
# 0       0.000570
# 1       0.028613
# 2       0.001384
# 3       0.010361
# 4       0.010184
# ...          ...
# 6981    0.029913
# 6982    0.001863
# 6983    0.000362
# 6984    0.001863
# 6985    0.005156
#
# [6986 rows x 13 columns]

# %%
df_d.isna().sum()
# Out:
# num_parts     0
# theme_name    0
# rgb1          0
# rgb2          0
# rgb3          0
# rgb4          0
# rgb5          0
# rgb6          0
# rgb7          0
# rgb8          0
# rgb9          0
# rgb10         0
# theme_frec    0
# dtype: int64

# %%
df_d = df_d[['num_parts','rgb1','rgb2','rgb3','rgb4','rgb5','rgb6','rgb7','rgb8','rgb9','rgb10','theme_frec','theme_name']]
df_d
# Out:
#       num_parts      rgb1      rgb2      rgb3      rgb4      rgb5      rgb6  \
# 0             4  0.114923  0.043669  0.202362  0.051455  0.096420  0.066931
# 1            43  0.114923  0.095333  0.202362  0.023578  0.096420  0.002723
# 2            20  0.202362  0.051455  0.013117  0.003657  0.004452  0.003399
# 3             2  0.114923  0.202362  0.096420  0.066931  0.095333  0.051455
# 4            10  0.114923  0.096420  0.202362  0.051455  0.066931  0.043669
# ...         ...       ...       ...       ...       ...       ...       ...
# 6981        447  0.095333  0.202362  0.075679  0.114923  0.043669  0.023578
# 6982        423  0.202362  0.096420  0.043669  0.066931  0.051455  0.013117
# 6983         10  0.202362  0.066931  0.114923  0.095333  0.023578  0.096420
# 6984        378  0.202362  0.096420  0.043669  0.066931  0.051455  0.013117
# 6985        253  0.095333  0.075679  0.202362  0.114923  0.096420  0.023578
#
#           rgb7      rgb8      rgb9     rgb10  theme_frec  \
# 0     0.013117  0.020410  0.023578  0.003457    0.000570
# 1     0.024417  0.002628  0.001968  0.066931    0.028613
# 2     0.013170  0.043669  0.096420  0.003395    0.001384
# 3     0.075679  0.020410  0.043669  0.024417    0.010361
# 4     0.020410  0.095333  0.013170  0.013117    0.010184
# ...        ...       ...       ...       ...         ...
# 6981  0.013117  0.024417  0.096420  0.051455    0.029913
# 6982  0.020410  0.114923  0.005968  0.075679    0.001863
# 6983  0.002116  0.002040  0.000562  0.007571    0.000362
# 6984  0.020410  0.114923  0.005968  0.075679    0.001863
# 6985  0.066931  0.006159  0.024417  0.051455    0.005156
#
#                    theme_name
# 0               Gravity Games
# 1                     Friends
# 2                  Insectoids
# 3                        Town
# 4                Supplemental
# ...                       ...
# 6981  Star Wars Episode 4/5/6
# 6982                   Jungle
# 6983    Series 17 Minifigures
# 6984                   Jungle
# 6985         Star Wars Rebels
#
# [6986 rows x 13 columns]
