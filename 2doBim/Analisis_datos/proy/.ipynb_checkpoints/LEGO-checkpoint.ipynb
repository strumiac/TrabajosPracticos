# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DATASET_PATH = "dataset"

# %%
sets = pd.read_csv(DATASET_PATH + "/sets.csv")

themes = pd.read_csv(DATASET_PATH + "/themes.csv")
themes.rename(columns = {'id':'theme_id'}, inplace = True)

sets = sets.merge(themes, on='theme_id', how='left')
sets.rename(columns = {'name_x':'set_name','name_y':'theme_name'}, inplace = True)

sets.set_num.nunique()
# Out:
# 11673

# %%
inv = pd.read_csv(DATASET_PATH + "/inventories.csv")
inv.set_num.nunique()
# Out:
# 11670

# %%
inv = inv.merge(sets, on='set_num', how='left')
inv.set_num.nunique()
# Out:
# 11670

# %%
inv_part = pd.read_csv(DATASET_PATH + "/inventory_parts.csv")

colors = pd.read_csv(DATASET_PATH + "/colors.csv")
colors.rename(columns = {'id':'color_id'}, inplace = True)

inv_part = inv_part.merge(colors, on='color_id', how='left')
inv_part.rename(columns = {'inventory_id':'id'}, inplace = True)
inv_part.shape
# Out:
# (580251, 8)

# %%
df = inv_part.merge(inv, on='id', how='left')
print('Cantidad de sets: ',df.set_num.nunique())
df.head()
# Out:
# Cantidad de sets:  10713
#    id     part_num  color_id  quantity is_spare              name     rgb  \
# 0   1     48379c01        72         1        f  Dark Bluish Gray  6C6E68
# 1   1        48395         7         1        f        Light Gray  9BA19D
# 2   1     mcsport6        25         1        f            Orange  FE8A18
# 3   1       paddle         0         1        f             Black  05131D
# 4   3  11816pr0005        78         1        f       Light Flesh  F6D7B3
#
#   is_trans  version set_num  \
# 0        f        1  7922-1
# 1        f        1  7922-1
# 2        f        1  7922-1
# 3        f        1  7922-1
# 4        f        1  3931-1
#
#                                             set_name  year  theme_id  \
# 0  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 1  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 2  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 3  McDonald's Sports Set Number 6 - Orange Vest S...  2004       460
# 4                                 Emma's Splash Pool  2012       494
#
#    num_parts     theme_name  parent_id
# 0          4  Gravity Games      458.0
# 1          4  Gravity Games      458.0
# 2          4  Gravity Games      458.0
# 3          4  Gravity Games      458.0
# 4         43        Friends        NaN

# %%
df_ = df.drop(['parent_id', 'theme_id', 'year', 'version', 'is_trans', 'is_spare',  'quantity',
                   'color_id',  'part_num',  'id'], axis = 'columns')
df_
# Out:
#                      name     rgb  set_num  \
# 0        Dark Bluish Gray  6C6E68   7922-1
# 1              Light Gray  9BA19D   7922-1
# 2                  Orange  FE8A18   7922-1
# 3                   Black  05131D   7922-1
# 4             Light Flesh  F6D7B3   3931-1
# ...                   ...     ...      ...
# 580246              Black  05131D  75090-2
# 580247  Light Bluish Gray  A0A5A9  75090-2
# 580248              White  FFFFFF  75090-2
# 580249              Black  05131D  75090-2
# 580250   Dark Bluish Gray  6C6E68  75090-2
#
#                                                  set_name  num_parts  \
# 0       McDonald's Sports Set Number 6 - Orange Vest S...          4
# 1       McDonald's Sports Set Number 6 - Orange Vest S...          4
# 2       McDonald's Sports Set Number 6 - Orange Vest S...          4
# 3       McDonald's Sports Set Number 6 - Orange Vest S...          4
# 4                                      Emma's Splash Pool         43
# ...                                                   ...        ...
# 580246                                Ezra's Speeder Bike        253
# 580247                                Ezra's Speeder Bike        253
# 580248                                Ezra's Speeder Bike        253
# 580249                                Ezra's Speeder Bike        253
# 580250                                Ezra's Speeder Bike        253
#
#               theme_name
# 0          Gravity Games
# 1          Gravity Games
# 2          Gravity Games
# 3          Gravity Games
# 4                Friends
# ...                  ...
# 580246  Star Wars Rebels
# 580247  Star Wars Rebels
# 580248  Star Wars Rebels
# 580249  Star Wars Rebels
# 580250  Star Wars Rebels
#
# [580251 rows x 6 columns]

# %%
df_.set_num.nunique()
# Out:
# 10713

# %%
count_colors = df_.rgb.value_counts().to_dict()
sum(count_colors.values())
# Out:
# 580251

# %%
df_g=df_.groupby('set_num',as_index=False)['rgb'].nunique()
print('Cantidad máxima de colores en set:', df_g.rgb.max())
# Out:
# Cantidad máxima de colores en set: 43

# %%
df_d=df_.drop_duplicates(ignore_index = True)
df_d.shape
df_d
# Out:
#                      name     rgb  set_num  \
# 0        Dark Bluish Gray  6C6E68   7922-1
# 1              Light Gray  9BA19D   7922-1
# 2                  Orange  FE8A18   7922-1
# 3                   Black  05131D   7922-1
# 4             Light Flesh  F6D7B3   3931-1
# ...                   ...     ...      ...
# 94317         Flat Silver  898788  75090-2
# 94318           Trans-Red  C91A09  75090-2
# 94319  Trans-Bright Green  D9E4A7  75090-2
# 94320         Dark Orange  A95500  75090-2
# 94321            Dark Tan  958A73  75090-2
#
#                                                 set_name  num_parts  \
# 0      McDonald's Sports Set Number 6 - Orange Vest S...          4
# 1      McDonald's Sports Set Number 6 - Orange Vest S...          4
# 2      McDonald's Sports Set Number 6 - Orange Vest S...          4
# 3      McDonald's Sports Set Number 6 - Orange Vest S...          4
# 4                                     Emma's Splash Pool         43
# ...                                                  ...        ...
# 94317                                Ezra's Speeder Bike        253
# 94318                                Ezra's Speeder Bike        253
# 94319                                Ezra's Speeder Bike        253
# 94320                                Ezra's Speeder Bike        253
# 94321                                Ezra's Speeder Bike        253
#
#              theme_name
# 0         Gravity Games
# 1         Gravity Games
# 2         Gravity Games
# 3         Gravity Games
# 4               Friends
# ...                 ...
# 94317  Star Wars Rebels
# 94318  Star Wars Rebels
# 94319  Star Wars Rebels
# 94320  Star Wars Rebels
# 94321  Star Wars Rebels
#
# [94322 rows x 6 columns]

# %%
df_d.pivot(index= 'set_num', columns = 'rgb')#, values=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21824/1975812166.py in <module>
# ----> 1 df_d.pivot(index= 'set_num', columns = 'rgb')#, values=None)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7868         from pandas.core.reshape.pivot import pivot
#    7869
# -> 7870         return pivot(self, index=index, columns=columns, values=values)
#    7871
#    7872     _shared_docs[
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8411         from pandas.core.reshape.reshape import unstack
#    8412
# -> 8413         result = unstack(self, level, fill_value)
#    8414
#    8415         return result.__finalize__(self, method="unstack")
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     476     if isinstance(obj, DataFrame):
#     477         if isinstance(obj.index, MultiIndex):
# --> 478             return _unstack_frame(obj, level, fill_value=fill_value)
#     479         else:
#     480             return obj.T.stack(dropna=False)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     499 def _unstack_frame(obj, level, fill_value=None):
#     500     if not obj._can_fast_transpose:
# --> 501         unstacker = _Unstacker(obj.index, level=level)
#     502         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#     503         return obj._constructor(mgr)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     138             )
#     139
# --> 140         self._make_selectors()
#     141
#     142     @cache_readonly
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     190
#     191         if mask.sum() < len(self.index):
# --> 192             raise ValueError("Index contains duplicate entries, cannot reshape")
#     193
#     194         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape
